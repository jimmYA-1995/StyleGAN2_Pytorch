# %% [markdown]
# 似乎有兩個版本的 deepfashion 資料，存在 ~/data/deepfashion/r256/images 內的資料看起來品質比較差，感覺是 resize 時影響到，但相對地背景的長方形比較窄，應該是先 resize 了一次才 padding
#
# update: 品質比較差的是直接從 deepfashion Gdrive 下載得到的，背景長方行賄比較窄，頭髮品質會比較差。
# 但還有一個問題未解決：我不知道從哪將原版的 jpg 轉成 png 後得到一版都不像的，有試過直接將 jpg 轉成 png pixel_value 不會有差別，就算是先加了一個等大小的 resize 也是一樣

# %%
from pathlib import Path
from random import sample

import numpy as np
from PIL import Image
from IPython.display import display

# %%
display(Image.open('id_00007788_06_4_full.png'), Image.open('B/train/id_00007788_06_4_full.jpg'), Image.open('/home/u3534611/data/deepfashion/r256/images/id_00007788_06_4_full.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FD1C3DB2670>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FD1C3C96280>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FD1C367EA00>

# %%
for p in sample(list(Path('B').glob('**/*.jpg')), 10):
    print(p)
    img1 = Image.open(p)
    img2 = Image.open(Path('/home/u3534611/data/deepfashion/r256/images') / f"{p.stem}.png")
    print(np.abs(np.asarray(img1) - np.asarray(img2)).sum())
#     d = np.array(img1) - np.array(img2)
#     display(Image.fromarray(np.clip(d + d.min(), 0, 255)))
    display(img1, img2)
# Out:
# B/train/id_00004141_06_1_front.jpg
# 9307356
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FD1C3C24760>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FD1C3C24190>
# B/train/id_00007788_06_4_full.jpg
# 10915714
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FD1C3C24730>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FD1C3C24490>
# B/val/id_00006678_06_4_full.jpg
# 11127720
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FD1C3C24850>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FD1C3C24460>
# B/train/id_00007284_03_4_full.jpg
# 8337178
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FD1C3C24A00>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FD1C3C24640>
# B/train/id_00007301_04_4_full.jpg
# 8636916
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FD1C3C24850>
# ...

# %%
/home/u3534611/data/deepfashion/r256/images/
